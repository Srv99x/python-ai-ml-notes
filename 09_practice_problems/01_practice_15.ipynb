# %% [markdown]
# ## Practice Problems and Concept ReinforcementThis notebook covers practice problems and concept reinforcement for file handling and string searching in Python.It includes examples of reading files, searching for specific words, and handling file closure.

# %% [markdown]
# ### File Handling and String SearchingFile handling in Python involves reading and writing files. The `open()` function is used to open a file.String searching involves checking if a specific word or phrase is present in a given string. The `in` operator is used for this purpose.

# %%
# Open the file 'poem.txt' in read modef = open("poem.txt")# Read the content of the filecontent = f.read()# Check if the word 'Twinkle' is present in the contentif("Twinkle" in content):    # Print a message if the word is found    print("The word twinkle is present in the content!")else:    # Print a message if the word is not found    print("The word twinkle is not present in the content!")# Close the filef.close()

# %% [markdown]
# ### Output and ExplanationThe output of this code will be either 'The word twinkle is present in the content!' or 'The word twinkle is not present in the content!', depending on whether the word 'Twinkle' is found in the file 'poem.txt'.A common mistake is forgetting to close the file after reading or writing, which can lead to file corruption or other issues.A quick tip is to use the `with` statement to open files, which automatically closes the file when you're done with it.

# %% [markdown]
# ## Key Takeaways* File handling in Python involves reading and writing files using the `open()` function.* String searching involves checking if a specific word or phrase is present in a given string using the `in` operator.* It's essential to close files after reading or writing to prevent file corruption or other issues.
