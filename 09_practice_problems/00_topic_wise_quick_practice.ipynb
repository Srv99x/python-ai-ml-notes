# %% [markdown]
# # Topic-Wise Quick Practice
#
# This notebook contains a series of quick practice problems designed to test your understanding of core Python concepts, from basic syntax to object-oriented programming.
#
# **Instructions:**
# 1.  Read the problem description for each task.
# 2.  Write your own code in the empty code cell provided to solve the problem.
# 3.  After you've attempted a solution, you can view a sample solution by clicking the "▶ Solution" dropdown.
