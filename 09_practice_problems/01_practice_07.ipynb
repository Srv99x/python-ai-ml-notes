# %% [markdown]
# ## Practice Problems and Concept ReinforcementThis notebook covers practice problems and concept reinforcement for a specific topic.It includes a simple while loop to calculate the sum of numbers from 0 to a given input number.

# %% [markdown]
# ### Getting User InputThe `input()` function is used to get user input.It returns a string, so we use `int()` to convert it to an integer.

# %%
# Get user input and convert it to an integern = int(input("Enter number: "))

# %% [markdown]
# The output of this cell will be a prompt for the user to enter a number.A common mistake is to forget to convert the input to the correct data type.A quick tip is to always validate user input to ensure it is in the expected format.

# %% [markdown]
# ### While LoopA while loop is used to repeat a block of code while a certain condition is true.The syntax is `while condition: code`.

# %%
# Initialize variablesi = 0sum = 0# While loop to calculate the sum of numbers from 0 to nwhile(i <= n):    sum += i    i += 1

# %% [markdown]
# The output of this cell will be the sum of numbers from 0 to the input number.A common mistake is to forget to increment the loop counter.A quick tip is to use a for loop instead of a while loop when possible.

# %% [markdown]
# ### Printing the ResultThe `print()` function is used to print the result.It can take any number of arguments, separated by commas.

# %%
# Print the resultprint(sum)

# %% [markdown]
# The output of this cell will be the final result.A common mistake is to forget to print the result.A quick tip is to use a debugger to step through the code and see the values of variables.

# %% [markdown]
# ## Key Takeaways* Use `input()` to get user input and convert it to the correct data type.* Use a while loop to repeat a block of code while a certain condition is true.* Use `print()` to print the result.* Always validate user input and use a debugger to step through the code.
