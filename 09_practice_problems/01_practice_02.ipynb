# %% [markdown]
# ## Practice Problems and Concept ReinforcementThis notebook covers practice problems and concept reinforcement for sets in Python.It demonstrates how to create a set, add elements to it, and print the set.

# %% [markdown]
# ### Sets in PythonA set in Python is an unordered collection of unique elements.It is used to store multiple items in a single variable.

# %%
# Create an empty sets = set()# Add elements to the setn = int(input("enter no.: "))s.add(n)n = int(input("enter no.: "))s.add(n)n = int(input("enter no.: "))s.add(n)n = int(input("enter no.: "))s.add(n)n = int(input("enter no.: "))s.add(n)n = int(input("enter no.: "))s.add(n)n = int(input("enter no.: "))s.add(n)n = int(input("enter no.: "))s.add(n)# Print the setprint(s)

# %% [markdown]
# ### Output and Common MistakesThe output will be a set of unique numbers entered by the user.A common mistake is trying to add duplicate elements to a set, which will be ignored.A quick tip is to use the `len()` function to get the number of elements in a set.

# %% [markdown]
# ## Key Takeaways* Sets are unordered collections of unique elements.* Sets are used to store multiple items in a single variable.* The `add()` method is used to add elements to a set.* The `len()` function is used to get the number of elements in a set.
