# %% [markdown]
# ## Temporary Code RunnerThis notebook is a temporary runner file used by the editor for quick tests.It is designed to help you understand specific concepts in Python.

# %% [markdown]
# ### Variable DeclarationIn Python, you can declare a variable using the assignment operator (=).The syntax pattern is: variable_name = value

# %%
# Declare a variable 'brand' without assigning a value will result in an errorbrand

# %% [markdown]
# The output will be an error because 'brand' is not defined.Common mistake: Forgetting to assign a value to a variable before using it.Quick tip: Always assign a value to a variable before using it to avoid errors.

# %% [markdown]
# ## Key Takeaways* Variables must be assigned a value before use.* Forgetting to assign a value will result in an error.
