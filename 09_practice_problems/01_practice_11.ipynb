# %% [markdown]
# ## Practice Problems and Concept ReinforcementThis notebook covers practice problems and concept reinforcement for temperature conversion.It includes a function to convert Fahrenheit to Celsius and demonstrates how to use it with user input.

# %% [markdown]
# ### Fahrenheit to Celsius Conversion FunctionThis function takes a temperature in Fahrenheit as input and returns the equivalent temperature in Celsius.The formula used is: `c = 5*(f-32)/9`

# %%
def f_to_c(f):    # Convert Fahrenheit to Celsius using the formula: c = 5*(f-32)/9    return 5*(f-32)/9

# %% [markdown]
# The output of this function will be the temperature in Celsius, which can be rounded to two decimal places for better readability.A common mistake is to forget to round the result, which can lead to a long decimal output.A quick tip is to use the `round()` function to limit the decimal places.

# %% [markdown]
# ### Getting User Input and Printing the ResultThis code gets the temperature in Fahrenheit from the user, converts it to Celsius using the `f_to_c()` function, and prints the result.The `input()` function is used to get the user input, and the `print()` function is used to display the result.

# %%
f = int(input("Enter temperature in F: "))c = f_to_c(f)# Print the result, rounded to two decimal placesprint(f"{round(c,2)} degree celsius")

# %% [markdown]
# The output of this code will be the temperature in Celsius, which is the result of the conversion.A common mistake is to enter a non-numeric value, which will cause an error.A quick tip is to use a try-except block to handle such errors and provide a meaningful error message.

# %% [markdown]
# ## Key Takeaways* Fahrenheit to Celsius conversion formula: `c = 5*(f-32)/9`* Using the `round()` function to limit decimal places* Getting user input using the `input()` function* Printing the result using the `print()` function
