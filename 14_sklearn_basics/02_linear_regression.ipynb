# %% [markdown]
# ## Linear Regression with scikit-learn
# This notebook covers the basics of linear regression, including simple and multiple linear regression, feature scaling, regularization, and assumptions of linear regression. It also includes practical machine learning scenarios.

# %% [markdown]
# ### Simple Linear Regression: y = mx + b
# Simple linear regression is used to predict a continuous target variable from a single feature. The goal is to find the best-fitting line that minimizes the residual sum of squares.

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import matplotlib.pyplot as plt

np.random.seed(42)

X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)  # Must be 2D
y = np.array([2, 4, 5, 4, 5])  # Target with noise

print("=== Simple Linear Regression ===")
print(f"X shape: {X.shape}, y shape: {y.shape}")

model = LinearRegression()
model.fit(X, y)

print(f"Coefficient (slope): {model.coef_[0]:.4f}")
print(f"Intercept: {model.intercept_:.4f}")
print(f"Equation: y = {model.coef_[0]:.4f}*x + {model.intercept_:.4f}")

y_pred = model.predict(X)
print(f"\nPredictions: {y_pred.round(2)}")
print(f"Actual: {y}")

mse = mean_squared_error(y, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y, y_pred)
r2 = r2_score(y, y_pred)

print(f"\nMSE: {mse:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"MAE: {mae:.4f}")
print(f"R²: {r2:.4f}")

# %% [markdown]
# The output of the simple linear regression model shows the coefficient (slope) and intercept of the best-fitting line. The predictions are also printed, along with the actual values. The performance metrics (MSE, RMSE, MAE, R²) are calculated to evaluate the model's performance. A common mistake is to ignore the assumptions of linear regression, and a quick tip is to always visualize the data before modeling.

# %% [markdown]
# ### Multiple Linear Regression
# Multiple linear regression is used to predict a continuous target variable from multiple features. The goal is to find the best-fitting hyperplane that minimizes the residual sum of squares.

# %%
from sklearn.datasets import make_regression

X_multi, y_multi = make_regression(n_samples=100, n_features=5, n_informative=3, noise=10, random_state=42)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_multi, y_multi, test_size=0.2, random_state=42)

model_multi = LinearRegression()
model_multi.fit(X_train, y_train)

print("\n" + "="*60)
print("\n=== Multiple Linear Regression ===")
print(f"Coefficients for 5 features: {model_multi.coef_.round(4)}")
print(f"Intercept: {model_multi.intercept_:.4f}")

feature_importance = np.abs(model_multi.coef_)
top_features = np.argsort(feature_importance)[::-1]
print(f"\nTop 3 most important features (by coefficient magnitude):")
for feat_idx in top_features[:3]:
    print(f"  Feature {feat_idx}: coef = {model_multi.coef_[feat_idx]:.4f}")

y_pred_test = model_multi.predict(X_test)
r2_train = model_multi.score(X_train, y_train)
r2_test = model_multi.score(X_test, y_test)

print(f"\nTrain R²: {r2_train:.4f}")
print(f"Test R²: {r2_test:.4f}")
if r2_train > r2_test + 0.1:
    print("→ Potential overfitting (train R² much higher than test)")

# %% [markdown]
# The output of the multiple linear regression model shows the coefficients for each feature and the intercept. The top 3 most important features are also printed, along with their coefficients. The train and test R² scores are calculated to evaluate the model's performance. A common mistake is to ignore feature importance, and a quick tip is to always use cross-validation to evaluate model performance.

# %% [markdown]
# ### Feature Scaling Importance
# Feature scaling is important in linear regression because it makes the coefficients comparable and speeds up optimization.

# %%
from sklearn.preprocessing import StandardScaler

print("\n" + "="*60)
print("\n=== Feature Scaling Impact ===")

X_unscaled = np.array([[1000, 0.5], [2000, 1.0], [3000, 1.5]]).astype(float)
y_scale = np.array([50, 100, 150])

model_unscaled = LinearRegression()
model_unscaled.fit(X_unscaled, y_scale)
print(f"Unscaled coefficients: {model_unscaled.coef_}")
print("First feature coefficient is small because feature has large values")

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_unscaled)
model_scaled = LinearRegression()
model_scaled.fit(X_scaled, y_scale)
print(f"\nScaled coefficients: {model_scaled.coef_}")
print("Coefficients now on same scale; easier to compare importance")

# %% [markdown]
# The output of the feature scaling example shows the coefficients before and after scaling. The coefficients are comparable after scaling, making it easier to compare feature importance. A common mistake is to ignore feature scaling, and a quick tip is to always use a standard scaler to scale features.

# %% [markdown]
# ### Regularization: Ridge and Lasso
# Regularization is used to prevent overfitting by penalizing large coefficients. Ridge regression uses L2 penalty, while Lasso regression uses L1 penalty.

# %%
from sklearn.linear_model import Ridge, Lasso

X_reg, y_reg = make_regression(n_samples=100, n_features=20, n_informative=5, noise=10, random_state=42)
X_train_reg, X_test_reg, y_train_reg, y_test_reg = train_test_split(X_reg, y_reg, test_size=0.2, random_state=42)

print("\n" + "="*60)
print("\n=== Regularization: Ridge vs Lasso ===")

model_linear = LinearRegression()
model_linear.fit(X_train_reg, y_train_reg)
train_linear = model_linear.score(X_train_reg, y_train_reg)
test_linear = model_linear.score(X_test_reg, y_test_reg)

model_ridge = Ridge(alpha=1.0)  # alpha controls strength
model_ridge.fit(X_train_reg, y_train_reg)
train_ridge = model_ridge.score(X_train_reg, y_train_reg)
test_ridge = model_ridge.score(X_test_reg, y_test_reg)

model_lasso = Lasso(alpha=0.5)
model_lasso.fit(X_train_reg, y_train_reg)
train_lasso = model_lasso.score(X_train_reg, y_train_reg)
test_lasso = model_lasso.score(X_test_reg, y_test_reg)

print(f"Linear:  Train R² = {train_linear:.4f}, Test R² = {test_linear:.4f}")
print(f"Ridge:   Train R² = {train_ridge:.4f}, Test R² = {test_ridge:.4f}")
print(f"Lasso:   Train R² = {train_lasso:.4f}, Test R² = {test_lasso:.4f}")

print(f"\nLasso selected {(model_lasso.coef_ != 0).sum()} out of 20 features")

# %% [markdown]
# The output of the regularization example shows the train and test R² scores for linear, ridge, and lasso regression. The number of features selected by lasso regression is also printed. A common mistake is to ignore regularization, and a quick tip is to always use cross-validation to evaluate model performance.

# %% [markdown]
# ### Assumptions of Linear Regression
# Linear regression assumes a linear relationship between the features and target variable, normal residuals, constant variance, and independence of observations.

# %%
print("\n" + "="*60)
print("\n=== Linear Regression Assumptions ===")

X_nonlinear = np.linspace(0, 2*np.pi, 100).reshape(-1, 1)
y_nonlinear = np.sin(X_nonlinear).ravel() + np.random.randn(100) * 0.1

model_nonlinear = LinearRegression()
model_nonlinear.fit(X_nonlinear, y_nonlinear)
y_pred_nonlinear = model_nonlinear.predict(X_nonlinear)
r2_nonlinear = r2_score(y_nonlinear, y_pred_nonlinear)

print("1. Linearity: relationship must be linear")
print(f"   Sine wave data with linear model: R² = {r2_nonlinear:.4f} (poor!)")

residuals = y_nonlinear - y_pred_nonlinear
print(f"\n2. Normality: residuals should be ~ normal")
print(f"   Residuals mean: {residuals.mean():.4f} (should be ≈ 0)")
print(f"   Residuals std: {residuals.std():.4f}")

print(f"\n3. Homoscedasticity: constant variance across predictions")
print(f"   Residual variance: {np.var(residuals):.4f}")

print(f"\n4. Independence: observations should be independent")
print("   Check: time series data, spatial clustering violates this")

# %% [markdown]
# The output of the assumptions example shows the R² score for a linear model on non-linear data. The residuals are also printed, along with their mean and standard deviation. A common mistake is to ignore the assumptions of linear regression, and a quick tip is to always visualize the data before modeling.

# %% [markdown]
# ### Practical ML Scenarios
# This section includes practical machine learning scenarios, such as house price prediction and model comparison with cross-validation.

# %%
print("\n" + "="*60)
print("ML Scenarios:\n")

prices = np.random.normal(300000, 50000, 100)
sqft = np.random.normal(2000, 500, 100)
X_house = sqft.reshape(-1, 1)
y_house = prices

model_house = LinearRegression()
model_house.fit(X_house, y_house)
print("House price prediction:")
print(f"  Coefficient (price per sqft): ${model_house.coef_[0]:.2f}")
print(f"  For 2500 sqft house: ${model_house.predict([[2500]])[0]:.2f}")

from sklearn.model_selection import cross_val_score
scores_linear = cross_val_score(LinearRegression(), X_multi, y_multi, cv=5, scoring='r2')
scores_ridge = cross_val_score(Ridge(), X_multi, y_multi, cv=5, scoring='r2')
print(f"\n5-fold CV scores:")
print(f"  Linear: {scores_linear.mean():.4f} (+/- {scores_linear.std():.4f})")
print(f"  Ridge:  {scores_ridge.mean():.4f} (+/- {scores_ridge.std():.4f})")

from sklearn.model_selection import GridSearchCV
param_grid = {'alpha': [0.1, 1.0, 10.0, 100.0]}
grid_search = GridSearchCV(Ridge(), param_grid, cv=5, scoring='r2')
grid_search.fit(X_train_reg, y_train_reg)
print(f"\nBest alpha: {grid_search.best_params_['alpha']}")
print(f"Best CV score: {grid_search.best_score_:.4f}")

# %% [markdown]
# The output of the practical ML scenarios shows the coefficient and prediction for house price prediction, as well as the 5-fold CV scores for linear and ridge regression. The best alpha and CV score for ridge regression are also printed. A common mistake is to ignore hyperparameter tuning, and a quick tip is to always use cross-validation to evaluate model performance.

# %% [markdown]
# ## Key Takeaways
# * Linear regression: minimize (actual - predicted)² for continuous targets.
# * Coefficients: feature importance (if scaled); intercept: baseline.
# * R²: proportion of variance explained (0-1, closer to 1 is better).
# * Ridge/Lasso: prevent overfitting via regularization (L2/L1 penalty).
# * Scale features: makes coefficients comparable and speeds optimization.
# * Assumptions: linear relationship, normal residuals, constant variance, independence.
